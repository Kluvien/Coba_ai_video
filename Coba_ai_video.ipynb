# %% [markdown]
# <a href="https://colab.research.google.com/github/Kluvien/Coba_ai_video/blob/main/Coba_ai_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content

# !git clone https://github.com/comfyanonymous/ComfyUI.git

# %cd /content/ComfyUI
# !pip install -r requirements.txt

# !wget -c https://huggingface.co/Linaqruf/animagine-xl/resolve/main/animagine-xl-3.1.safetensors -P ./models/checkpoints/

# !npm install -g localtunnel
import urllib
password = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n")
print("\n" + "="*40)
print(f"PASSWORD TUNNEL KAMU: {password}")
print("="*40 + "\n")

# !python main.py --dont-print-server & npx localtunnel --port 8188
# Out:
# /content
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 38136, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 38136 (delta 39), reused 23 (delta 23), pack-reused 38086 (from 4)
# Receiving objects: 100% (38136/38136), 86.36 MiB | 21.85 MiB/s, done.
# Resolving deltas: 100% (25611/25611), done.
# /content/ComfyUI
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 91.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 106.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 MB 12.3 MB/s eta 0:00:00
# ...
